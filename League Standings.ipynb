# %% [markdown]
# # Initial play around with Football Data 2020
# - importing CSV
# - Creating / inspecting a dataframe
# - Playing around with displaying some data
# ------------------

# %%
import pandas as pd

# %%
season1819 = pd.read_csv ("/Users/callumoconnor/Desktop/season_1819 copy 2.csv")

# %%
print(season1819.head(5))
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# ...

# %%
season1819.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.568421    1.252632    0.678947    0.573684   14.134211   11.144737
# std      1.312836    1.180031    0.860802    0.766958    5.855371    4.654002
# min      0.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   18.000000   14.000000
# max      6.000000    6.000000    4.000000    3.000000   36.000000   25.000000
#
#               HST         AST          HF          AF  ...    BbAv<2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.778947    3.928947   10.152632   10.305263  ...    2.126895
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set(color_codes=True)
# %matplotlib inline

# %%
import sys

# %%
print (season1819.groupby('HomeTeam').sum())
# Out:
#                 FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  \
# HomeTeam
# Arsenal           42    16    14     8  256  217   96   75  218  256  128
# Bournemouth       30    25    15    10  229  249   82   82  187  232   96
# Brighton          19    28    10    12  200  224   53   79  221  167   90
# Burnley           24    32    14    12  210  287   66   94  184  193   80
# Cardiff           21    38     8    18  230  254   68   92  195  232   95
# Chelsea           39    12    16     6  325  157  118   49  154  202  120
# Crystal Palace    19    23     8     6  294  223   76   66  180  211  130
# Everton           30    21    14    11  279  190   85   68  218  226  119
# Fulham            22    36     9    20  274  253   86  108  199  159  102
# Huddersfield      10    31     4    18  203  223   57   89  214  196   85
# Leicester         24    20    10    12  298  187   99   62  184  191  108
# ...

# %%
import numpy as np

# %%
df.describe(include=np.object)
# Out:
#         Div        Date  HomeTeam  AwayTeam  FTR  HTR   Referee
# count   380         380       380       380  380  380       380
# unique    1         108        20        20    3    3        18
# top      E0  12/05/2019  Brighton  Brighton    H    D  A Taylor
# freq    380          10        19        19  181  148        32

# %%
df["Referee"].value_counts()
# Out:
# A Taylor      32
# M Oliver      30
# M Atkinson    29
# M Dean        29
# J Moss        27
# K Friend      27
# A Marriner    27
# C Pawson      26
# C Kavanagh    24
# P Tierney     24
# S Attwell     20
# L Mason       19
# L Probert     18
# G Scott       17
# D Coote       11
# R East        10
# S Hooper       8
# A Madley       2
# Name: Referee, dtype: int64

# %%
pd.set_option("display.max.columns", None)

# %%
pd.set_option("display.precision", 2)

# %%
season1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 62 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
# ...

# %%
season1819.loc[season1819["HomeTeam"] == "Man","HomeTeam"].value_counts()
# Out:
# Series([], Name: HomeTeam, dtype: int64)

# %%
season1819.loc[season1819["HomeTeam"] == "Man United","Date"].agg(("min","max"))
# Out:
# min    02/03/2019
# max    30/12/2018
# Name: Date, dtype: object

# %%
season1819.loc[season1819["HomeTeam"] == "Man United","FTHG"].sum()
# Out:
# 33

# %%
## data structures / series objects tutorial https://realpython.com/pandas-python-explore-dataset/

# %%
revenues = pd.Series([5555, 7000, 1980])
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980])

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
index=["Amsterdam", "Toronto", "Tokyo"])

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
"Tokyo" in city_employee_count
# Out:
# True

# %%
current_decade = season1819[season1819["Date"] > '01/04/2019']
current_decade.shape
# Out:
# (376, 62)

# %%
season1819[
(season1819["FTAG"] == 0) &
##(season1819["Date"] > '01/01/2019') &
(season1819["FTHG"] >= 1) &
(season1819["AwayTeam"].str.startswith("Man"))
##(season1819["HomeTeam"] == "Man United")
]
# Out:
#     Div        Date HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 154  E0  08/12/2018  Chelsea    Man City     2     0   H     1     0   H
# 296  E0  10/03/2019  Arsenal  Man United     2     0   H     1     0   H
# 344  E0  21/04/2019  Everton  Man United     4     0   H     2     0   H
#
#        Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 154   M Oliver   8  14    5    4  12  11   1  13   2   0   0   0   4.00
# 296     J Moss  14  14    3    4  12  18   5   2   2   2   0   0   2.40
# 344  P Tierney  15   7    8    1  11   7  10   2   1   1   0   0   3.25
#
#      B365D  B365A   BWH  BWD   BWA   IWH   IWD  IWA   PSH   PSD   PSA   WHH  \
# 154    3.8   1.95  3.90  3.7  1.91  4.00  3.60  1.9  4.00  3.75  1.99  3.80
# 296    3.6   3.00  2.35  3.5  2.95  2.35  3.55  2.9  2.45  3.55  3.04  2.38
# 344    3.5   2.30  3.20  3.4  2.25  3.10  3.45  2.3  3.23  3.55  2.34  3.20
#
# ...

# %%
homeGoals = season1819["FTHG"]
type(homeGoals)
homeGoals.sum()
# Out:
# 596

# %%
season1819.groupby("Referee", sort=False)["FTHG"].sum()
# Out:
# Referee
# A Marriner    37
# K Friend      37
# M Dean        44
# C Kavanagh    41
# M Atkinson    35
# J Moss        48
# C Pawson      25
# M Oliver      39
# A Taylor      59
# G Scott       40
# L Mason       31
# S Attwell     35
# P Tierney     37
# L Probert     28
# D Coote       24
# R East        25
# S Hooper       7
# A Madley       4
# Name: FTHG, dtype: int64

# %%
season1819[
(season1819["HomeTeam"] == "Man United") &
(season1819["Date"] > "2019")
].groupby(["Date", "FTR"])["Div"].count()
# Out:
# Date        FTR
# 22/09/2018  D      1
# 24/02/2019  D      1
# 24/04/2019  A      1
# 24/11/2018  D      1
# 26/12/2018  H      1
# 27/08/2018  A      1
# 28/04/2019  D      1
# 28/10/2018  H      1
# 29/01/2019  D      1
# 30/03/2019  H      1
# 30/12/2018  H      1
# Name: Div, dtype: int64

# %% [markdown]
# ------------------
# # Resumed playing around with data Dec-2021
# - Messing around with SQL to no avail
# - Attempting to calculate a league table from the dataset
# - Played around with groupby, sum, classes, adding new columns to a df
# ------------------

# %%
### Playing around with SQL in Python
import sqlite3
df = pd.read_csv ("/Users/callumoconnor/Desktop/season_1819 copy 2.csv")
conn = sqlite3.connect("Any_Database_Name.db")
df.to_sql('Some_Table_Name', conn)
sql_string = 'SELECT * FROM Some_Table_Name'
df = pd.read_sql(sql_string, conn)
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-1cdba2b01751> in <module>
#       3 df = pd.read_csv ("/Users/callumoconnor/Desktop/season_1819 copy 2.csv")
#       4 conn = sqlite3.connect("Any_Database_Name.db")
# ----> 5 df.to_sql('Some_Table_Name', conn)
#       6 sql_string = 'SELECT * FROM Some_Table_Name'
#       7 df = pd.read_sql(sql_string, conn)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
# ...

# %%
print (season1819.groupby('HomeTeam').sum())
# Out:
#                 FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  \
# HomeTeam
# Arsenal           42    16    14     8  256  217   96   75  218  256  128
# Bournemouth       30    25    15    10  229  249   82   82  187  232   96
# Brighton          19    28    10    12  200  224   53   79  221  167   90
# Burnley           24    32    14    12  210  287   66   94  184  193   80
# Cardiff           21    38     8    18  230  254   68   92  195  232   95
# Chelsea           39    12    16     6  325  157  118   49  154  202  120
# Crystal Palace    19    23     8     6  294  223   76   66  180  211  130
# Everton           30    21    14    11  279  190   85   68  218  226  119
# Fulham            22    36     9    20  274  253   86  108  199  159  102
# Huddersfield      10    31     4    18  203  223   57   89  214  196   85
# Leicester         24    20    10    12  298  187   99   62  184  191  108
# ...

# %%
### Add new columns to define home / away team points

def f(row):
    if row['FTHG'] == row['FTAG']:
        val = 1
    elif row['FTHG'] > row['FTAG']:
        val = 3
    else:
        val = 0
    return val

def g(row):
    if row['FTHG'] == row['FTAG']:
        val = 1
    elif row['FTAG'] > row['FTHG']:
        val = 3
    else:
        val = 0
    return val

# %%
df['Home_Team_Points'] = df.apply(f, axis=1)
df['Away_Team_Points'] = df.apply(g, axis=1)

# %%
df
# Out:
#     Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1    E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2    E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3    E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4    E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
# ..   ..         ...           ...             ...   ...   ...  ..   ...   ...
# 375  E0  12/05/2019     Liverpool          Wolves     2     0   H     1     0
# 376  E0  12/05/2019    Man United         Cardiff     0     2   A     0     1
# 377  E0  12/05/2019   Southampton    Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019     Tottenham         Everton     2     2   D     1     0
# 379  E0  12/05/2019       Watford        West Ham     1     4   A     0     2
#
# ...

# %%
### sum points for home / away teams & combine the 2
##df.groupby('HomeTeam')['Home_Team_Points'].sum() + df.groupby('AwayTeam')['Away_Team_Points'].sum()

new_df = df.groupby('HomeTeam')['Home_Team_Points'].sum() + df.groupby('AwayTeam')['Away_Team_Points'].sum()
##new_df = new_df.sort_values(by = ['user_ID', 'amount'], ascending=[True,False])
##new_df.groupby("HomeTeam", sort=True)
print(new_df)
# Out:
# HomeTeam
# Arsenal           70
# Bournemouth       45
# Brighton          36
# Burnley           40
# Cardiff           34
# Chelsea           72
# Crystal Palace    49
# Everton           54
# Fulham            26
# Huddersfield      16
# Leicester         52
# Liverpool         97
# Man City          98
# Man United        66
# Newcastle         45
# Southampton       39
# Tottenham         71
# Watford           50
# West Ham          52
# Wolves            57
# dtype: int64

# %% [markdown]
# ------------------
# ## Random game simulation using classes
# ------------------

# %%
### Using classes to simulate a football league
### Classes / OOP not neccesary for data analysis, better for 2 sided games, stick to functions

class Team:
    def __init__(self, name, skill):
        self.name = name
        self.skill = skill
        self.points = self.goals_for = self.goals_against = \
                     self.wins = self.draws = self.losses = 0

# %%
t1 = Team("Man City", 3)

# %%
league_size = 4
teams = []
for _ in range(league_size):
    teams.append(Team(input("Name of team "+str(_)+": "),
                      int(input("Team "+str(_)+"'s skill level: "))))
# Out:
# Name of team 0: Man City
# Team 0's skill level: 3
# Name of team 1: Huddersfield
# Team 1's skill level: 1
# Name of team 2: Crystal Palace
# Team 2's skill level: 2
# Name of team 3: Watford
# Team 3's skill level: 1

# %%
for team in teams:
    print(team.name, team.skill)
# Out:
# Man City 3
# Huddersfield 1
# Crystal Palace 2
# Watford 1

# %%
for team in sorted(teams, key=lambda t: t.points):
    print(team.name, team.skill, team.points, ...)
# Out:
# Man City 3 0 Ellipsis
# Huddersfield 1 0 Ellipsis
# Crystal Palace 2 0 Ellipsis
# Watford 1 0 Ellipsis

# %% [markdown]
# ------------------
# # Figured out the problem with league calculation
# - Can't calculate league table with data in it's current format - https://alysivji.github.io/pl-analysis-part1-finding-longest-consecutive-position-streak.html
#
# ------------------

# %%
## converting each matchup into 2 rows
## one where each team is 'current_team' and opponent is identfied
import math
import numpy as np
import pandas as pd

season1819['H'] = season1819['HomeTeam']
season1819['A'] = season1819['AwayTeam']
cols_to_keep = ['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG',
                'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee']

team_results = pd.melt(
    season1819, 
    id_vars=cols_to_keep, 
    value_vars=['H', 'A'],
    var_name='Home/Away',
    value_name='Team')

team_results['Opponent'] = np.where(team_results['Team'] == team_results['HomeTeam'],
                                    team_results['AwayTeam'],
                                    team_results['HomeTeam'])

team_results.head(2)
# Out:
#   Div        Date     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  10/08/2018   Man United  Leicester     2     1   H     1     0   H
# 1  E0  11/08/2018  Bournemouth    Cardiff     2     0   H     1     0   H
#
#       Referee Home/Away         Team   Opponent
# 0  A Marriner         H   Man United  Leicester
# 1    K Friend         H  Bournemouth    Cardiff

# %%
points_map = {
    'W': 3,
    'D': 1,
    'L': 0
}

def get_result(score, score_opp):
    if score == score_opp:
        return 'D'
    elif score > score_opp:
        return 'W'
    else:
        return 'L'

# %%
# full time goals
team_results['Goals'] = np.where(team_results['Team'] == team_results['HomeTeam'],
                                 team_results['FTHG'],
                                 team_results['FTAG'])
team_results['Goals_Opp'] = np.where(team_results['Team'] != team_results['HomeTeam'],
                                     team_results['FTHG'],
                                     team_results['FTAG'])
team_results['Result'] = np.vectorize(get_result)(team_results['Goals'], team_results['Goals_Opp'])
team_results['Points'] = team_results['Result'].map(points_map)

# 1st half goals
team_results['1H_Goals'] = np.where(team_results['Team'] == team_results['HomeTeam'],
                                    team_results['HTHG'],
                                    team_results['HTAG'])
team_results['1H_Goals_Opp'] = np.where(team_results['Team'] != team_results['HomeTeam'],
                                        team_results['HTHG'],
                                        team_results['HTAG'])
team_results['1H_Result'] = np.vectorize(get_result)(team_results['1H_Goals'], team_results['1H_Goals_Opp'])
team_results['1H_Points'] = team_results['1H_Result'].map(points_map)

# 2nd half goals
team_results['2H_Goals'] = team_results['Goals'] - team_results['1H_Goals']
team_results['2H_Goals_Opp'] = team_results['Goals_Opp'] - team_results['1H_Goals_Opp']
team_results['2H_Result'] = np.vectorize(get_result)(team_results['2H_Goals'], team_results['2H_Goals_Opp'])
team_results['2H_Points'] = team_results['2H_Result'].map(points_map)

# %%
# Drop unnecessary columns and sort by date
cols_to_drop = ['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR']
team_results = (team_results
                    .drop(cols_to_drop, axis=1)
                    .sort_values(by=['Date', 'Referee']))

# %%
team_results.head()
# Out:
#     Div        Date     Referee Home/Away       Team   Opponent  Goals  \
# 200  E0  01/01/2019     G Scott         H    Arsenal     Fulham      4
# 580  E0  01/01/2019     G Scott         A     Fulham    Arsenal      1
# 201  E0  01/01/2019    K Friend         H    Cardiff  Tottenham      0
# 581  E0  01/01/2019    K Friend         A  Tottenham    Cardiff      3
# 202  E0  01/01/2019  M Atkinson         H    Everton  Leicester      0
#
#      Goals_Opp Result  Points  1H_Goals  1H_Goals_Opp 1H_Result  1H_Points  \
# 200          1      W       3         1             0         W          3
# 580          4      L       0         0             1         L          0
# 201          3      L       0         0             3         L          0
# 581          0      W       3         3             0         W          3
# 202          1      L       0         0             0         D          1
#
#      2H_Goals  2H_Goals_Opp 2H_Result  2H_Points
# ...

# %%
# Testing the standings function against real world data
(team_results
     .groupby('Team')
     .sum()['Points']
     .sort_values(ascending=False))
# Out:
# Team
# Man City          98
# Liverpool         97
# Chelsea           72
# Tottenham         71
# Arsenal           70
# Man United        66
# Wolves            57
# Everton           54
# Leicester         52
# West Ham          52
# Watford           50
# Crystal Palace    49
# Newcastle         45
# Bournemouth       45
# Burnley           40
# Southampton       39
# Brighton          36
# Cardiff           34
# Fulham            26
# Huddersfield      16
# Name: Points, dtype: int64

# %% [markdown]
# --------------------
# # Start from scratch
# - Combine data from 5 different seasons
# - Calculate league standings
# - Explore data
# --------------------

# %%
import math
import numpy as np
import pandas as pd

# %%
season1819 = pd.read_csv ("/Users/callumoconnor/Desktop/season_1819 copy 2.csv")
season1718 = pd.read_csv ("/Users/callumoconnor/Desktop/season-1718_csv.csv")
season1617 = pd.read_csv ("/Users/callumoconnor/Desktop/season-1617_csv.csv")
season1516 = pd.read_csv ("/Users/callumoconnor/Desktop/season-1516_csv.csv")
season1415 = pd.read_csv ("/Users/callumoconnor/Desktop/season-1415_csv.csv")

# %%
## Add season identifier column to each dataframe
season1819['Season'] = '18-19'
season1718['Season'] = '17-18'
season1617['Season'] = '16-17'
season1516['Season'] = '15-16'
season1415['Season'] = '14-15'

# %%
## Concatenate 5 dataframes into 1
frames = [season1819,season1718,season1617,season1516,season1415]
combineddata = pd.concat(frames)

# %%
## Convert each match into 2 rows

combineddata['H'] = combineddata['HomeTeam']
combineddata['A'] = combineddata['AwayTeam']
cols_to_keep = ['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG',
                'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee','Season']

team_results = pd.melt(
    combineddata, 
    id_vars=cols_to_keep, 
    value_vars=['H', 'A'],
    var_name='Home/Away',
    value_name='Team')

team_results['Opponent'] = np.where(team_results['Team'] == team_results['HomeTeam'],
                                    team_results['AwayTeam'],
                                    team_results['HomeTeam'])

team_results.head(2)
# Out:
#   Div        Date     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  10/08/2018   Man United  Leicester     2     1   H     1     0   H
# 1  E0  11/08/2018  Bournemouth    Cardiff     2     0   H     1     0   H
#
#       Referee Season Home/Away         Team   Opponent
# 0  A Marriner  18-19         H   Man United  Leicester
# 1    K Friend  18-19         H  Bournemouth    Cardiff

# %%
## define points
points_map = {
    'W': 3,
    'D': 1,
    'L': 0
}

def get_result(score, score_opp):
    if score == score_opp:
        return 'D'
    elif score > score_opp:
        return 'W'
    else:
        return 'L'

# %%
# full time goals
team_results['Goals'] = np.where(team_results['Team'] == team_results['HomeTeam'],
                                 team_results['FTHG'],
                                 team_results['FTAG'])
team_results['Goals_Opp'] = np.where(team_results['Team'] != team_results['HomeTeam'],
                                     team_results['FTHG'],
                                     team_results['FTAG'])
team_results['Result'] = np.vectorize(get_result)(team_results['Goals'], team_results['Goals_Opp'])
team_results['Points'] = team_results['Result'].map(points_map)

# 1st half goals
team_results['1H_Goals'] = np.where(team_results['Team'] == team_results['HomeTeam'],
                                    team_results['HTHG'],
                                    team_results['HTAG'])
team_results['1H_Goals_Opp'] = np.where(team_results['Team'] != team_results['HomeTeam'],
                                        team_results['HTHG'],
                                        team_results['HTAG'])
team_results['1H_Result'] = np.vectorize(get_result)(team_results['1H_Goals'], team_results['1H_Goals_Opp'])
team_results['1H_Points'] = team_results['1H_Result'].map(points_map)

# 2nd half goals
team_results['2H_Goals'] = team_results['Goals'] - team_results['1H_Goals']
team_results['2H_Goals_Opp'] = team_results['Goals_Opp'] - team_results['1H_Goals_Opp']
team_results['2H_Result'] = np.vectorize(get_result)(team_results['2H_Goals'], team_results['2H_Goals_Opp'])
team_results['2H_Points'] = team_results['2H_Result'].map(points_map)

# %%
# Drop unnecessary columns and sort by date
cols_to_drop = ['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR']
team_results = (team_results
                    .drop(cols_to_drop, axis=1)
                    .sort_values(by=['Date', 'Referee']))

# %%
## Create a DF for each season (now that they have the new columns added & have 2 rows for each match)
## Need to rethink this approach
Standings1819 = team_results.loc[team_results['Season'] == '18-19']
Standings1718 = team_results.loc[team_results['Season'] == '17-18']
Standings1617 = team_results.loc[team_results['Season'] == '16-17']
Standings1516 = team_results.loc[team_results['Season'] == '15-16']
Standings1415 = team_results.loc[team_results['Season'] == '14-15']

# %%
## Groupby points sum for each season & print each
overallstandings1819 = (Standings1819
     .groupby(['Team'])
     .sum()['Points']
     .sort_values(ascending=False))
overallstandings1718 = (Standings1718
     .groupby(['Team'])
     .sum()['Points']
     .sort_values(ascending=False))
overallstandings1617 = (Standings1617
     .groupby(['Team'])
     .sum()['Points']
     .sort_values(ascending=False))
overallstandings1516 = (Standings1516
     .groupby(['Team'])
     .sum()['Points']
     .sort_values(ascending=False))
overallstandings1415 = (Standings1415
     .groupby(['Team'])
     .sum()['Points']
     .sort_values(ascending=False))

print(overallstandings1819)
print(overallstandings1718)
print(overallstandings1617)
print(overallstandings1516)
print(overallstandings1415)
# Out:
# Team
# Man City          98
# Liverpool         97
# Chelsea           72
# Tottenham         71
# Arsenal           70
# Man United        66
# Wolves            57
# Everton           54
# Leicester         52
# West Ham          52
# Watford           50
# Crystal Palace    49
# Newcastle         45
# Bournemouth       45
# Burnley           40
# Southampton       39
# Brighton          36
# Cardiff           34
# Fulham            26
# Huddersfield      16
# Name: Points, dtype: int64
# Team
# Man City          100
# Man United         81
# Tottenham          77
# Liverpool          75
# Chelsea            70
# Arsenal            63
# Burnley            54
# Everton            49
# Leicester          47
# Newcastle          44
# Crystal Palace     44
# Bournemouth        44
# West Ham           42
# Watford            41
# Brighton           40
# Huddersfield       37
# Southampton        36
# Stoke              33
# Swansea            33
# West Brom          31
# ...
